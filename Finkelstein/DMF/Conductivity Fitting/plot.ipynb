# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.optimize import curve_fit
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Starting concentrations for runs:

# %%
runs = {1: {'a': 0.0984, 'b': 0.0138},
  2: {'a': 0.0997, 'b': 0.0791},
  3: {'a': 0.159, 'b': 0.0785},
  4: {'a': 0.0933, 'b': 0.0642},
  5: {'a': 0.134, 'b': 0.100}
       }

# %%
# integrated second order irreversible expression
def c_second(x,a,b,k):
  return (a - b) * ( 1 / ( 1 - b/a * np.exp( - k * x * (a - b) ) ) - 1 )

# %% [markdown]
# ## Chose subsitutent and run for plotting:

# %%
while True:
    run = input('Enter which run you wish to get the data for: ')

    try:
        with open(f'dmf_cond_new_{run}.csv') as f:
            reader = csv.reader(f)
            data = np.array(list(reader)).astype(float)
        break
    except:
        print('Invalid run')

a = runs[int(run)]['a']
b = runs[int(run)]['b']
# Out:
# Enter which run you wish to get the data for:  1
# Invalid run
# Enter which run you wish to get the data for:  2
# Invalid run

# %% [markdown]
# ## Plot Conductivity

# %%
plt.figure(figsize=(8,6))

x = data[:,0]
y = data[:,1]

plt.scatter(x,y,s=2,alpha=0.1,marker='o')
plt.plot()
# Out:
# []
